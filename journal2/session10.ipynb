# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.standard_normal(1000)
ax = plt.subplot()
ax.hist(x, bins=100)
ax.set_xlabel("x")
ax.set_ylabel("count")
plt.savefig("session10.pdf")
